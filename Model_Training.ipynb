# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
import pickle
from scipy.cluster.hierarchy import fcluster

# %%
data=pd.read_csv('Medicine_Details.csv')

# %%
print(data.dtypes)
# Out:
# Medicine Name         object
# Composition           object
# Uses                  object
# Side_effects          object
# Image URL             object
# Manufacturer          object
# Excellent Review %     int64
# Average Review %       int64
# Poor Review %          int64
# dtype: object

# %%
data.head(1)
# Out:
#              Medicine Name          Composition  \
# 0  Avastin 400mg Injection  Bevacizumab (400mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
#
#                                            Image URL  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                    Manufacturer  Excellent Review %  Average Review %  \
# 0  Roche Products India Pvt Ltd                  22                56
#
#    Poor Review %
# 0             22

# %%
data[['Main Element', 'Numeric Value']] = data['Composition'].str.extract(r'([a-zA-Z\s]+)\s*\((\d+mg)\)')

# %%
data = data.drop(columns=['Composition'])

# %%
data= data[['Medicine Name', 'Main Element', 'Numeric Value', 'Uses', 'Side_effects', 
         'Image URL', 'Manufacturer', 'Excellent Review %', 'Average Review %', 'Poor Review %']]

# %%
data.head(3)
# Out:
#               Medicine Name   Main Element Numeric Value  \
# 0   Avastin 400mg Injection   Bevacizumab          400mg
# 1  Augmentin 625 Duo Tablet  Amoxycillin           500mg
# 2       Azithral 500 Tablet  Azithromycin          500mg
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# 1  Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 2                     Nausea Abdominal pain Diarrhea
#
#                                            Image URL  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                            Manufacturer  Excellent Review %  Average Review %  \
# 0          Roche Products India Pvt Ltd                  22                56
# 1  Glaxo SmithKline Pharmaceuticals Ltd                  47                35
# 2           Alembic Pharmaceuticals Ltd                  39                40
#
#    Poor Review %
# 0             22
# 1             18
# 2             21

# %%
data.columns
# Out:
# Index(['Medicine Name', 'Main Element', 'Numeric Value', 'Uses',
#        'Side_effects', 'Image URL', 'Manufacturer', 'Excellent Review %',
#        'Average Review %', 'Poor Review %'],
#       dtype='object')

# %%
data= data[['Medicine Name', 'Main Element', 'Numeric Value', 'Excellent Review %', 'Average Review %', 'Poor Review %']]

# %%
data.head(5)
# Out:
#               Medicine Name   Main Element Numeric Value  Excellent Review %  \
# 0   Avastin 400mg Injection   Bevacizumab          400mg                  22
# 1  Augmentin 625 Duo Tablet  Amoxycillin           500mg                  47
# 2       Azithral 500 Tablet  Azithromycin          500mg                  39
# 3          Ascoril LS Syrup            NaN           NaN                  24
# 4         Aciloc 150 Tablet    Ranitidine          150mg                  34
#
#    Average Review %  Poor Review %
# 0                56             22
# 1                35             18
# 2                40             21
# 3                41             35
# 4                37             29

# %%
data.isnull().sum()
# Out:
# Medicine Name            0
# Main Element          3710
# Numeric Value         3710
# Excellent Review %       0
# Average Review %         0
# Poor Review %            0
# dtype: int64

# %%
data= data.dropna(subset=['Main Element'])

# %%
data['Numeric Value(in mg)'] = data['Numeric Value'].str.extract('(\d+)').astype(int)
data.drop("Numeric Value", inplace=True, axis=1)

# %%
data.head(6)
# Out:
#               Medicine Name   Main Element  Excellent Review %  \
# 0   Avastin 400mg Injection   Bevacizumab                   22
# 1  Augmentin 625 Duo Tablet  Amoxycillin                    47
# 2       Azithral 500 Tablet  Azithromycin                   39
# 4         Aciloc 150 Tablet    Ranitidine                   34
# 5      Allegra 120mg Tablet  Fexofenadine                   35
# 6            Avil 25 Tablet   Pheniramine                   40
#
#    Average Review %  Poor Review %  Numeric Value(in mg)
# 0                56             22                   400
# 1                35             18                   500
# 2                40             21                   500
# 4                37             29                   150
# 5                42             23                   120
# 6                34             26                    25

# %%
main_element_counts = data['Main Element'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=main_element_counts.index, y=main_element_counts.values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel('Main Element')
plt.ylabel('Frequency')
plt.title('Frequency of Each Main Element in MediMatch Dataset')
plt.show()

# %%
data = pd.get_dummies(data, columns=['Main Element'], prefix='Element')

# %%
data.head()
# Out:
#               Medicine Name  Excellent Review %  Average Review %  \
# 0   Avastin 400mg Injection                  22                56
# 1  Augmentin 625 Duo Tablet                  47                35
# 2       Azithral 500 Tablet                  39                40
# 4         Aciloc 150 Tablet                  34                37
# 5      Allegra 120mg Tablet                  35                42
#
#    Poor Review %  Numeric Value(in mg)  Element_   Element_    \
# 0             22                   400      False       False
# 1             18                   500      False       False
# 2             21                   500      False       False
# 4             29                   150      False       False
# 5             23                   120      False       False
#
#    Element_  Albendazole   Element_  Solifenacin   \
# 0                   False                   False
# 1                   False                   False
# 2                   False                   False
# 4                   False                   False
# 5                   False                   False
#
#    Element_ Alpha Lipoic Acid   ...  Element_Voriconazole   Element_Warfarin   \
# 0                        False  ...                  False              False
# 1                        False  ...                  False              False
# 2                        False  ...                  False              False
# 4                        False  ...                  False              False
# 5                        False  ...                  False              False
#
#    Element_Xylitol   Element_Zinc Carnosine   Element_Ziprasidone   \
# 0             False                    False                 False
# 1             False                    False                 False
# 2             False                    False                 False
# 4             False                    False                 False
# 5             False                    False                 False
#
#    Element_Zoledronic acid   Element_Zolmitriptan   Element_Zonisamide   \
# 0                     False                  False                False
# 1                     False                  False                False
# 2                     False                  False                False
# 4                     False                  False                False
# 5                     False                  False                False
#
#    Element_carnitine   Element_phosphate
# 0               False               False
# 1               False               False
# 2               False               False
# 4               False               False
# 5               False               False
#
# [5 rows x 694 columns]

# %%
scaler=StandardScaler()
data[['Numeric Value(in mg)', 'Excellent Review %', 'Average Review %', 'Poor Review %']] = scaler.fit_transform(
    data[['Numeric Value(in mg)', 'Excellent Review %', 'Average Review %', 'Poor Review %']]
)

# %%
Z = linkage(data.drop(columns=['Medicine Name']), method='ward')
# why ward ?? becuse it minimizes variance between clusters

plt.figure(figsize=(10, 6))
dendrogram(Z, labels=data['Medicine Name'].values, leaf_rotation=90, leaf_font_size=8)
plt.title("Hierarchical Clustering Dendrogram (MediMatch)")
plt.xlabel("Medicine")
plt.ylabel("Distance")
plt.show()

# %%
with open('linkage_matrix.pkl', 'wb') as f:
    pickle.dump(Z, f)

n_clusters = 7
cluster_assignments = fcluster(Z, n_clusters, criterion='maxclust')

with open('cluster_assignments.pkl', 'wb') as f:
    pickle.dump(cluster_assignments, f)

data['Cluster'] = cluster_assignments
data.to_csv('medimatch_data.csv', index=False)
